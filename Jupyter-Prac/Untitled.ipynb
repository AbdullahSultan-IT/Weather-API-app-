# %% [markdown]
# # load the dataframe

# %%
import pandas as pd

# %%
import matplotlib

# %%
df = pd.read_csv("data_small/TG_STAID000001.txt",skiprows=20, parse_dates=["    DATE"])

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
df[10:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %%
df['   TG']
# Out:
# 0          21
# 1          46
# 2          31
# 3          37
# 4          31
#          ...
# 59316   -9999
# 59317   -9999
# 59318   -9999
# 59319   -9999
# 59320   -9999
# Name:    TG, Length: 59321, dtype: int64

# %% [markdown]
# #simple statics

# %%
df['   TG'[.maen()
# Out:
#   Cell In[18], line 1
#     df['   TG'[.maen()
#                ^
# SyntaxError: invalid syntax

# %%
df['   TG'[.mean()'   TG'
# Out:
#   Cell In[19], line 1
#     df['   TG'[.mean()
#                ^
# SyntaxError: invalid syntax

# %%
df['   TG'].mean()
# Out:
# np.float64(-991.1500649011311)

# %%
df.loc(df['   TG'] != -9999]
# Out:
#   Cell In[21], line 1
#     df.loc(df['   TG'] != -9999]
#                                ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
df.loc(df['   TG'] != -9999)df.loc(df['   TG'] != -9999]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/0z/f68hhpks31b27_7v66chvyr80000gn/T/ipykernel_1759/1152652004.py in ?()
# ----> 1 df.loc(df['   TG'] != -9999)
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexing.py in ?(self, axis)
#     735         # we need to return a copy of ourselves
#     736         new_self = type(self)(self.name, self.obj)
#     737
#     738         if axis is not None:
# --> 739             axis_int_none = self.obj._get_axis_number(axis)
#     740         else:
#     741             axis_int_none = axis
#     742         new_self.axis = axis_int_none
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py in ?(cls, axis)
#     576     @classmethod
#     577     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     578         try:
# ...

# %%
df.loc[df['   TG'] != -9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
df.loc[df['   TG'] != -9999]['   TG'] / 10
# Out:
# 0        2.1
# 1        4.6
# 2        3.1
# 3        3.7
# 4        3.1
#         ...
# 53655    8.0
# 53656    7.0
# 53657    7.1
# 53658    6.3
# 53659    8.4
# Name:    TG, Length: 53103, dtype: float64

# %%
df.loc[df['   TG'] != -9999]['   TG'] / 10
# Out:
# 0        2.1
# 1        4.6
# 2        3.1
# 3        3.7
# 4        3.1
#         ...
# 53655    8.0
# 53656    7.0
# 53657    7.1
# 53658    6.3
# 53659    8.4
# Name:    TG, Length: 53103, dtype: float64

# %%
df.loc[df['   TG'] != -9999]['   TG'].max() / 10
# Out:
# np.float64(26.2)

# %%
df['   TG'].hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df['   TG'].hist()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/plotting/_core.py:128, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      47 def hist_series(
#      48     self: Series,
#      49     by=None,
#    (...)     60     **kwargs,
#      61 ):
#      62     """
#      63     Draw histogram of the input series using matplotlib.
#      64
#    (...)    126         >>> hist = ser.groupby(level=0).hist()
#     127     """
# --> 128     plot_backend = _get_plot_backend(backend)
#     129     return plot_backend.hist_series(
#     130         self,
#     131         by=by,
#    (...)    141         **kwargs,
#     142     )
#
# ...

# %%
pip3 install matplotlib
# Out:
#   Cell In[36], line 1
#     pip3 install matplotlib
#          ^
# SyntaxError: invalid syntax

# %%
df['   TG'].hist()
# Out:
# <Axes: >

# %%
df.loc[df['   TG'] != -9999]['   TG'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # get certain cells

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
df.loc[df['    DATE']=="1860-01-05"]['   TG']
# Out:
# 4    31
# Name:    TG, dtype: int64

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %% [markdown]
# #calc a new column

# %%
df["tg0"] = df['   TG'].mask(df['   TG']==-9999)

# %%
df ["tg"] = df['tg0'] / 10

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   tg   tg0
# 0          1   35381 1860-01-01     21      0  2.1  21.0
# 1          1   35381 1860-01-02     46      0  4.6  46.0
# 2          1   35381 1860-01-03     31      0  3.1  31.0
# 3          1   35381 1860-01-04     37      0  3.7  37.0
# 4          1   35381 1860-01-05     31      0  3.1  31.0
# ...      ...     ...        ...    ...    ...  ...   ...
# 59316      1   35381 2022-05-27  -9999      9  NaN   NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN   NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN   NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN   NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN   NaN
#
# [59321 rows x 7 columns]

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     tg   tg0
# 0          1   35381 1860-01-01     21      0    2.1  21.0
# 1          1   35381 1860-01-02     46      0    4.6  46.0
# 2          1   35381 1860-01-03     31      0    3.1  31.0
# 3          1   35381 1860-01-04     37      0    3.7  37.0
# 4          1   35381 1860-01-05     31      0    3.1  31.0
# ...      ...     ...        ...    ...    ...    ...   ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9   NaN
# 59317      1   35381 2022-05-28  -9999      9 -999.9   NaN
# 59318      1   35381 2022-05-29  -9999      9 -999.9   NaN
# 59319      1   35381 2022-05-30  -9999      9 -999.9   NaN
# 59320      1   35381 2022-05-31  -9999      9 -999.9   NaN
#
# [59321 rows x 7 columns]

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   tg   tg0
# 0          1   35381 1860-01-01     21      0  2.1  21.0
# 1          1   35381 1860-01-02     46      0  4.6  46.0
# 2          1   35381 1860-01-03     31      0  3.1  31.0
# 3          1   35381 1860-01-04     37      0  3.7  37.0
# 4          1   35381 1860-01-05     31      0  3.1  31.0
# ...      ...     ...        ...    ...    ...  ...   ...
# 59316      1   35381 2022-05-27  -9999      9  NaN   NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN   NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN   NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN   NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN   NaN
#
# [59321 rows x 7 columns]

# %%
df["fehrinhite"] = df['tg'] * (9/5) + 32

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   tg   tg0  fehrinhite
# 0          1   35381 1860-01-01     21      0  2.1  21.0       35.78
# 1          1   35381 1860-01-02     46      0  4.6  46.0       40.28
# 2          1   35381 1860-01-03     31      0  3.1  31.0       37.58
# 3          1   35381 1860-01-04     37      0  3.7  37.0       38.66
# 4          1   35381 1860-01-05     31      0  3.1  31.0       37.58
# ...      ...     ...        ...    ...    ...  ...   ...         ...
# 59316      1   35381 2022-05-27  -9999      9  NaN   NaN         NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN   NaN         NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN   NaN         NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN   NaN         NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN   NaN         NaN
#
# [59321 rows x 8 columns]

# %% [markdown]
# # plotting

# %%
df["fehrinhite"].hist()
# Out:
# <Axes: >
